# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv(r"C:\Users\acer\Downloads\Diwali.xls" , encoding='ISO-8859-1')

# %%
data.head(5)
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28               0
# 1  1000732     Kartik  P00110942      F     26-35   35               1
# 2  1001990      Bindu  P00118542      F     26-35   35               1
# 3  1001425     Sudevi  P00237842      M      0-17   16               0
# 4  1000588       Joni  P00057942      M     26-35   28               1
#
#             State      Zone       Occupation Product_Category  Orders  \
# 0     Maharashtra   Western       Healthcare             Auto       1
# 1  Andhra Pradesh  Southern             Govt             Auto       3
# 2   Uttar Pradesh   Central       Automobile             Auto       3
# 3       Karnataka  Southern     Construction             Auto       2
# 4         Gujarat   Western  Food Processing             Auto       2
#
#     Amount  Status  unnamed1
# 0  23952.0     NaN       NaN
# 1  23934.0     NaN       NaN
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11251 entries, 0 to 11250
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11251 non-null  int64
#  1   Cust_name         11251 non-null  object
#  2   Product_ID        11251 non-null  object
#  3   Gender            11251 non-null  object
#  4   Age Group         11251 non-null  object
#  5   Age               11251 non-null  int64
#  6   Marital_Status    11251 non-null  int64
#  7   State             11251 non-null  object
#  8   Zone              11251 non-null  object
#  9   Occupation        11251 non-null  object
#  10  Product_Category  11251 non-null  object
#  11  Orders            11251 non-null  int64
#  12  Amount            11239 non-null  float64
#  13  Status            0 non-null      float64
#  14  unnamed1          0 non-null      float64
# dtypes: float64(3), int64(4), object(8)
# memory usage: 1.3+ MB

# %%
data.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount', 'Status', 'unnamed1'],
#       dtype='object')

# %%
data.drop(columns= 'unnamed1')
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0      1002903    Sanskriti  P00125942      F     26-35   28               0
# 1      1000732       Kartik  P00110942      F     26-35   35               1
# 2      1001990        Bindu  P00118542      F     26-35   35               1
# 3      1001425       Sudevi  P00237842      M      0-17   16               0
# 4      1000588         Joni  P00057942      M     26-35   28               1
# ...        ...          ...        ...    ...       ...  ...             ...
# 11246  1000695      Manning  P00296942      M     18-25   19               1
# 11247  1004089  Reichenbach  P00171342      M     26-35   33               0
# 11248  1001209        Oshin  P00201342      F     36-45   40               0
# 11249  1004023       Noonan  P00059442      M     36-45   37               0
# 11250  1002744      Brumley  P00281742      F     18-25   19               0
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11251 entries, 0 to 11250
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11251 non-null  int64
#  1   Cust_name         11251 non-null  object
#  2   Product_ID        11251 non-null  object
#  3   Gender            11251 non-null  object
#  4   Age Group         11251 non-null  object
#  5   Age               11251 non-null  int64
#  6   Marital_Status    11251 non-null  int64
#  7   State             11251 non-null  object
#  8   Zone              11251 non-null  object
#  9   Occupation        11251 non-null  object
#  10  Product_Category  11251 non-null  object
#  11  Orders            11251 non-null  int64
#  12  Amount            11239 non-null  float64
#  13  Status            0 non-null      float64
#  14  unnamed1          0 non-null      float64
# dtypes: float64(3), int64(4), object(8)
# memory usage: 1.3+ MB

# %%
data.drop(columns = ['Status' , 'unnamed1'] , axis =1 , inplace = True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11251 entries, 0 to 11250
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11251 non-null  int64
#  1   Cust_name         11251 non-null  object
#  2   Product_ID        11251 non-null  object
#  3   Gender            11251 non-null  object
#  4   Age Group         11251 non-null  object
#  5   Age               11251 non-null  int64
#  6   Marital_Status    11251 non-null  int64
#  7   State             11251 non-null  object
#  8   Zone              11251 non-null  object
#  9   Occupation        11251 non-null  object
#  10  Product_Category  11251 non-null  object
#  11  Orders            11251 non-null  int64
#  12  Amount            11239 non-null  float64
# dtypes: float64(1), int64(4), object(8)
# memory usage: 1.1+ MB

# %%
data.isna().sum()
# Out:
# User_ID              0
# Cust_name            0
# Product_ID           0
# Gender               0
# Age Group            0
# Age                  0
# Marital_Status       0
# State                0
# Zone                 0
# Occupation           0
# Product_Category     0
# Orders               0
# Amount              12
# dtype: int64

# %%
data.dropna(inplace= True)

# %%
data.isna().sum()
# Out:
# User_ID             0
# Cust_name           0
# Product_ID          0
# Gender              0
# Age Group           0
# Age                 0
# Marital_Status      0
# State               0
# Zone                0
# Occupation          0
# Product_Category    0
# Orders              0
# Amount              0
# dtype: int64

# %%
data.head(2)
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28               0
# 1  1000732     Kartik  P00110942      F     26-35   35               1
#
#             State      Zone  Occupation Product_Category  Orders   Amount
# 0     Maharashtra   Western  Healthcare             Auto       1  23952.0
# 1  Andhra Pradesh  Southern        Govt             Auto       3  23934.0

# %%
data['Age Group'].unique()
# Out:
# array(['26-35', '0-17', '18-25', '51-55', '46-50', '55+', '36-45'],
#       dtype=object)

# %%
data.Gender.unique()
# Out:
# array(['F', 'M'], dtype=object)

# %%
data.Marital_Status.unique()
# Out:
# array([0, 1], dtype=int64)

# %%
data.State.unique()
# Out:
# array(['Maharashtra', 'Andhra\xa0Pradesh', 'Uttar Pradesh', 'Karnataka',
#        'Gujarat', 'Himachal Pradesh', 'Delhi', 'Jharkhand', 'Kerala',
#        'Haryana', 'Madhya Pradesh', 'Bihar', 'Rajasthan', 'Uttarakhand',
#        'Telangana', 'Punjab'], dtype=object)

# %%
data.rename(columns = { 'Amount' : 'Total_amount'} , inplace = True)

# %%
data.head(5)
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28               0
# 1  1000732     Kartik  P00110942      F     26-35   35               1
# 2  1001990      Bindu  P00118542      F     26-35   35               1
# 3  1001425     Sudevi  P00237842      M      0-17   16               0
# 4  1000588       Joni  P00057942      M     26-35   28               1
#
#             State      Zone       Occupation Product_Category  Orders  \
# 0     Maharashtra   Western       Healthcare             Auto       1
# 1  Andhra Pradesh  Southern             Govt             Auto       3
# 2   Uttar Pradesh   Central       Automobile             Auto       3
# 3       Karnataka  Southern     Construction             Auto       2
# 4         Gujarat   Western  Food Processing             Auto       2
#
#    Total_amount
# 0       23952.0
# 1       23934.0
# 2       23924.0
# 3       23912.0
# 4       23877.0

# %%
data['State'].replace( {'Andhra\xa0Pradesh' : 'Andhra Pradesh'} , inplace = True)

# %%
data.State.unique()
# Out:
# array(['Maharashtra', 'Andhra Pradesh', 'Uttar Pradesh', 'Karnataka',
#        'Gujarat', 'Himachal Pradesh', 'Delhi', 'Jharkhand', 'Kerala',
#        'Haryana', 'Madhya Pradesh', 'Bihar', 'Rajasthan', 'Uttarakhand',
#        'Telangana', 'Punjab'], dtype=object)

# %%
data.Zone.unique()
# Out:
# array(['Western', 'Southern', 'Central', 'Northern', 'Eastern'],
#       dtype=object)

# %%
data.Occupation.unique()
# Out:
# array(['Healthcare', 'Govt', 'Automobile', 'Construction',
#        'Food Processing', 'Lawyer', 'Media', 'Banking', 'Retail',
#        'IT Sector', 'Aviation', 'Hospitality', 'Agriculture', 'Textile',
#        'Chemical'], dtype=object)

# %% [raw]
#                     Sales value Age Group vs Total amount

# %%
data.head(2)
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28               0
# 1  1000732     Kartik  P00110942      F     26-35   35               1
#
#             State      Zone  Occupation Product_Category  Orders  Total_amount
# 0     Maharashtra   Western  Healthcare             Auto       1       23952.0
# 1  Andhra Pradesh  Southern        Govt             Auto       3       23934.0

# %%
sns.barplot( x= data['Age Group'] , y = data.Total_amount )
# Out:
# <Axes: xlabel='Age Group', ylabel='Total_amount'>

# %%
plt.figure(figsize=(12,6))
sns.barplot( x= data['Age Group'] , y = data.Total_amount , hue = data.Gender );

# %%
plt.figure(figsize=(12,6))
df = sns.barplot( x= data['Age Group'] , y = data.Total_amount , hue = data.Gender )
for bars in df.containers:
    df.bar_label(bars);

# %%
plt.figure(figsize=(8,4))
ax = sns.countplot( x= data['Age Group'] , hue = data.Gender)
for bars in ax.containers:
    ax.bar_label(bars);

# %%
data.head(2)
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28               0
# 1  1000732     Kartik  P00110942      F     26-35   35               1
#
#             State      Zone  Occupation Product_Category  Orders  Total_amount
# 0     Maharashtra   Western  Healthcare             Auto       1       23952.0
# 1  Andhra Pradesh  Southern        Govt             Auto       3       23934.0

# %%
plt.figure(figsize=(12,6))
df_Age = data.groupby(['Age Group'],  as_index = False )['Total_amount'].sum().sort_values(by= "Total_amount" ,   ascending = False)
sns.barplot( x = df_Age['Age Group'] , y= df_Age.Total_amount , data = df_Age);

# %%
data.head(2)
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28               0
# 1  1000732     Kartik  P00110942      F     26-35   35               1
#
#             State      Zone  Occupation Product_Category  Orders  Total_amount
# 0     Maharashtra   Western  Healthcare             Auto       1       23952.0
# 1  Andhra Pradesh  Southern        Govt             Auto       3       23934.0

# %%
plt.figure(figsize = (12,6))
df_State = data.groupby(['State'], as_index = False)['Total_amount'].sum().sort_values( by= 'Total_amount' , ascending = False ).head(8)
sns.barplot( x = df_State.State , y = df_State.Total_amount );

# %%
data.head(2)
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28               0
# 1  1000732     Kartik  P00110942      F     26-35   35               1
#
#             State      Zone  Occupation Product_Category  Orders  Total_amount
# 0     Maharashtra   Western  Healthcare             Auto       1       23952.0
# 1  Andhra Pradesh  Southern        Govt             Auto       3       23934.0

# %%
df_zone = data.groupby(['Zone'] , as_index = False)['Total_amount'].sum().sort_values( by = 'Total_amount' , ascending = False)
sns.barplot( x = df_zone.Zone , y = df_zone.Total_amount);

# %%
data.head(1)
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28               0
#
#          State     Zone  Occupation Product_Category  Orders  Total_amount
# 0  Maharashtra  Western  Healthcare             Auto       1       23952.0

# %%
plt.figure(figsize=(12,6))
df_occupation = data.groupby(['Occupation'] , as_index = False)['Total_amount'].sum().sort_values( by = 'Total_amount' , ascending = False).head(8)
sns.barplot( x= df_occupation.Occupation , y= df_occupation.Total_amount);

# %%
plt.figure(figsize=(12,6))
df_cust = data.groupby(['Cust_name'] , as_index = False)['Total_amount'].sum().sort_values( by = 'Total_amount' , ascending = False).head(8)
sns.barplot( x= df_cust.Cust_name , y= df_cust.Total_amount);

# %%
data.head(2)
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28               0
# 1  1000732     Kartik  P00110942      F     26-35   35               1
#
#             State      Zone  Occupation Product_Category  Orders  Total_amount
# 0     Maharashtra   Western  Healthcare             Auto       1       23952.0
# 1  Andhra Pradesh  Southern        Govt             Auto       3       23934.0

# %%
data.Product_ID.nunique()
# Out:
# 2350

# %%
plt.figure(figsize=(12,6))
df_product = data.groupby(['Product_ID'] , as_index = False)['Total_amount'].sum().sort_values( by = 'Total_amount' , ascending= False).head(11)
sns.barplot( x= df_product.Product_ID , y= df_product.Total_amount );

# %% [raw]
#                                   COUNT PLOT

# %%
data.head(2)
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28               0
# 1  1000732     Kartik  P00110942      F     26-35   35               1
#
#             State      Zone  Occupation Product_Category  Orders  Total_amount
# 0     Maharashtra   Western  Healthcare             Auto       1       23952.0
# 1  Andhra Pradesh  Southern        Govt             Auto       3       23934.0

# %%
data.head(2)
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28               0
# 1  1000732     Kartik  P00110942      F     26-35   35               1
#
#             State      Zone  Occupation Product_Category  Orders   Amount  \
# 0     Maharashtra   Western  Healthcare             Auto       1  23952.0
# 1  Andhra Pradesh  Southern        Govt             Auto       3  23934.0
#
#    Status  unnamed1
# 0     NaN       NaN
# 1     NaN       NaN

# %%
df = sns.countplot( x= data['Age Group'])
for bars in df.containers:
    df.bar_label(bars);

# %%
sd = sns.countplot( x= data['Marital_Status'] , hue = data.Gender)
for bars in sd.containers:
    sd.bar_label(bars);

# %%
data.head(1)
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28               0
#
#          State     Zone  Occupation Product_Category  Orders   Amount  Status  \
# 0  Maharashtra  Western  Healthcare             Auto       1  23952.0     NaN
#
#    unnamed1
# 0       NaN

# %%
plt.hist( x= data['Age Group'] );

# %%
data.head(2)
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28               0
# 1  1000732     Kartik  P00110942      F     26-35   35               1
#
#             State      Zone  Occupation Product_Category  Orders  Total_amount
# 0     Maharashtra   Western  Healthcare             Auto       1       23952.0
# 1  Andhra Pradesh  Southern        Govt             Auto       3       23934.0

# %%
plt.pie( data.Total_amount);

# %%
plt.pie( data['Age Group');
# Out:
#   Cell In[100], line 1
#     plt.pie( data['Age Group');
#                              ^
# SyntaxError: closing parenthesis ')' does not match opening parenthesis '['

# %%
import matplotlib.pyplot as plt

# Assuming 'Age Group' is the column name from your DataFrame 'data'
plt.figure(figsize=(8, 8))
data['Age Group'].value_counts().plot(kind='pie', autopct='%1.1f%%')
plt.title('Pie chart of Age Group')
plt.ylabel('')  # Removing the y-label
plt.show()
